# %%
import pandas as pd

df = pd.read_parquet("../shared_data/outputs/knowledgebase/embeddings/PCI-DSS-v4_0_1-docling-pic-annot_chunks_embeddings.parquet")

df.tail()
# Out:
#                                   chunk_id  chunk_index  \
# 1007  0fecab00-7db4-4add-bf16-513e1d9ba066         1007
# 1008  05d59d05-6595-4565-bea1-5775fc6a072c         1008
# 1009  a6f57de9-16be-40ed-9d35-8eb9c89be3bf         1009
# 1010  0da397d9-b6c6-43da-9eb1-d4f417df9814         1010
# 1011  288b7e5e-effb-4864-9a99-20c021d67db5         1011
#
#                                                    text  token_count  \
# 1007  | Service Provider | Business entity that is n...         1867
# 1008  | Term | Definition |\n| ---------------------...         1645
# 1009  | Strong Cryptography | Cryptography is a meth...         2540
# 1010  | TDES | Acronym for 'Triple Data Encryption S...         2463
# 1011  | Trusted Network | Network of an entity that ...         1955
#
#              source                                          embedding
# 1007  PCI DSS 4.0.1  [-0.059444136917591095, 0.018054421991109848, ...
# ...
